# %% [markdown]
# <a href="https://colab.research.google.com/github/ronkiks/SALARIES/blob/main/Copy_of_SUPERMARKET_DONE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Libraries:
# Import numpy as np:
# numpy: numpy is the core library for numerical computing in Python. It provides powerful tools for working with arrays, matrices, and mathematical functions.
#
# Import pandas as pd: is a powerful library for data manipulation and analysis. It introduces the DataFrame, a versatile data structure for organizing and working with tabular data (like spreadsheets or CSV files).
#
# Import matplotlib.pyplot as plt: is a core library for creating static, interactive, and animated visualizations in Python. It provides a wide range of plotting functions for various types of charts and graphs.
#
# Import seaborn as sns:is a library built on top of matplotlib that provides a higher-level interface for creating statistically informative and visually appealing visualizations. It offers a variety of plot types and themes, often preferred for data exploration and presentation.

# %%
df = pd.read_csv('/content/supermarket_sales - Sheet1.csv')
df.head()
# Out:
#     Invoice ID Branch       City Customer type              Product line  \
# 0  750-67-8428   R1C1     Yangon      Customer         Health and beauty
# 1  226-31-3081      C  Naypyitaw        Normal  Electronic \naccessories
# 2  631-41-3108      A     Yangon        Normal        Home and lifestyle
# 3  123-19-1176      A     Yangon      Customer         Health and beauty
# 4  373-73-7910      A     Yangon        Normal         Sports and travel
#
#    Unit price  Quantity Review Quantity  Check Tax 5%     Total        Date  \
# 0       67.99       7.0               7    NaN  23.8%   $475.93    1/5/2019
# 1       15.28       5.0               5    NaN   3.8%    $76.40    3/8/2019
# 2       46.33       7.0               7    NaN  16.2%   $324.31    3/3/2019
# 3       58.22       8.0               8    NaN  23.3%   $465.76   1/27/2019
# 4       86.31       7.0               7    NaN  30.2%   $604.17    2/8/2019
#
# ...

# %% [markdown]
# Documentation:
#
# pd.read_csv(): is use to customize how pd.read_csv() reads your data. It includes options for handling things like:
# Delimiters (other than commas if needed)
# Headers
# Missing values
# Data types
# And much more.
# df.head(): This is a built-in method of the Pandas DataFrame. Here's more about it:
# You can specify the number of rows to display by providing an argument to head(). For example, to see the first 10 rows, you would use df.head(10).

# %%
df = df.fillna(0)
df.head()
# Out:
#     Invoice ID Branch       City Customer type              Product line  \
# 0  750-67-8428   R1C1     Yangon      Customer         Health and beauty
# 1  226-31-3081      C  Naypyitaw        Normal  Electronic \naccessories
# 2  631-41-3108      A     Yangon        Normal        Home and lifestyle
# 3  123-19-1176      A     Yangon      Customer         Health and beauty
# 4  373-73-7910      A     Yangon        Normal         Sports and travel
#
#    Unit price  Quantity Review Quantity  Check Tax 5%     Total        Date  \
# 0       67.99       7.0               7    0.0  23.8%   $475.93    1/5/2019
# 1       15.28       5.0               5    0.0   3.8%    $76.40    3/8/2019
# 2       46.33       7.0               7    0.0  16.2%   $324.31    3/3/2019
# 3       58.22       8.0               8    0.0  23.3%   $465.76   1/27/2019
# 4       86.31       7.0               7    0.0  30.2%   $604.17    2/8/2019
#
# ...

# %% [markdown]
# Documentation:
# df = df.fillna(0): is line fills any missing values (NaN) in the DataFrame df with the value 0.
#
# df.head(): is a line displays the first 5 rows of the DataFrame df after the missing values have been filled. It allows you to see the effect of the fillna() method.
